# %% [markdown]
# # AstroGraphAnomaly — Run Full (pipeline + full plots)
#
# Ce notebook exécute `tools/run_full.py` (1 commande) pour générer **scored.csv**, **graph_full.graphml**, puis la suite complète de plots.

# %%
# !git clone --depth 1 https://github.com/dalozedidier-dot/AstroGraphAnomaly.git
# %cd AstroGraphAnomaly
# !python -m pip install -q --upgrade pip
# !pip -q install -r requirements.txt

# %%
# !python tools/run_full.py csv --in-csv data/sample_gaia_like.csv --out results/colab_run_full --top-k 30 --knn-k 8 --engine isolation_forest

# %%
from pathlib import Path
from IPython.display import Image, display
p = Path('results/colab_run_full/plots')
for name in sorted([x.name for x in p.glob('*.png')]):
    display(Image(filename=str(p/name)))
