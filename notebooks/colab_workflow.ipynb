# %% [markdown]
# # AstroGraphAnomaly — Colab workflow
# Ce notebook suppose que le dépôt est sur GitHub.
#
# ## 1) Clone + deps

# %%
# Remplacez l'URL par votre dépôt
# !git clone https://github.com/<USER>/<REPO>.git
# %cd <REPO>
# !pip -q install -r requirements.txt

# %% [markdown]
# ## 2) Run CSV offline (test)

# %%
# !python run_workflow.py --mode csv --in-csv data/sample_gaia_like.csv --out results/colab_csv --plots --explain-top 5

# %% [markdown]
# ## 3) Run Gaia (online)

# %%
# Exemple (centre galactique)
# !python run_workflow.py --mode gaia --ra 266.4051 --dec -28.936175 --radius-deg 0.5 --limit 2000 --out results/colab_gaia --plots --explain-top 5

# %% [markdown]
# ## 4) Visualiser les outputs

# %%
import pandas as pd
df = pd.read_csv('results/colab_csv/top_anomalies.csv')
df.head(10)
