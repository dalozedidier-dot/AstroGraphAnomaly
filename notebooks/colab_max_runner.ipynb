# %% [markdown]
# # AstroGraphAnomaly — Colab Max Runner
#
# Objectif: exécuter `tools/run_max_all.py` pour produire un maximum d'outputs (offline), puis option Gaia.
#
# Gaia est désactivé par défaut (quota/réseau). Pour l'activer, définir `RUN_GAIA=1`.

# %%
# !git clone --depth 1 https://github.com/dalozedidier-dot/AstroGraphAnomaly.git
# %cd AstroGraphAnomaly
# !python -m pip install -q --upgrade pip
# !pip -q install -r requirements.txt

# %%
# Ajoute les scripts 'tools/' depuis ton repo si tu les as commit.
# Sinon: upload le dossier tools/ du zip dans ton repo, puis re-clone.

# Offline max runs
# !python tools/run_max_all.py

# %%
# Gaia optionnel (décommenter)
# import os
# os.environ['RUN_GAIA'] = '1'
# os.environ['AGA_LIMIT'] = '1200'
# !python tools/run_max_all.py
